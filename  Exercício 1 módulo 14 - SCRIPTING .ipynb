# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_JAN.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_FEV.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_MAR.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_ABR.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_MAI.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_JUN.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os 

sns.set_theme()

sinasc = pd.read_csv('./input/SINASC_RO_2019_DEZ.csv')


def plota_pivot_table(df, value, index, func, ylabel, xlabel, opcao='nada'):
    if opcao == 'nada':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).plot(figsize=[15, 5])
    elif opcao == 'sort':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).sort_values(value).plot(figsize=[15, 5])
    elif opcao == 'unstack':
        pd.pivot_table(df, values=value, index=index,
                      aggfunc=func).unstack().plot(figsize=[15, 5])
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    return None

max_data = sinasc.DTNASC.max()[:7]

#Criacao das pastas
os.makedirs('./output/figs/'+max_data, exist_ok=True) 

plota_pivot_table(sinasc, 'IDADEMAE', 'DTNASC', 'count', 'quantidade de nascimento', 'data de nascimento')
plt.savefig('./output/figs/'+max_data+'/qtde nascimento por data')

plota_pivot_table(sinasc, 'IDADEMAE',['DTNASC', 'SEXO'], 'mean', 'IDADE DA MAE', ['DTNASC', 'SEXO'], 'unstack')
plt.savefig('./output/figs/'+max_data+'/media idade mae por sexo')

plota_pivot_table(sinasc, 'PESO', 'ESCMAE', 'median', 'Peso', 'ESCMAE','sort')
plt.savefig('./output/figs/'+max_data+'/mediana peso por escolaridade mae')

plota_pivot_table(sinasc, 'APGAR1', 'GESTACAO', 'mean', 'apgar1 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar1 por gestacao.png')

plota_pivot_table(sinasc, 'APGAR5', 'GESTACAO', 'mean', 'apgar5 medio','gestacao','sort')
plt.savefig('./output/figs/'+max_data+'/media apgar5 por gestacao.png')

# %% [markdown]
# Para tornar o processo mais automatizado para os proximos meses/anos,
# poderia ser implementado alguma funçao que busca automaticamente o arquivo, filtrando pelo mes e ano. Padronizando os nomes dos arquivos seria possivel criar uma funcao que busca cada mes gerando todo codigo acima.
